# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('clientes.xlsx')
df.to_csv('tabeladeclientes.csv', index=False)
pd.read_csv('tabeladeclientes.csv')
display(df)
# Out:
#                             NOME                NOME_FANTASIA TIPO_DOCUMENTO  \
# 0                raquel teixeira              RAQUEL TEIXEIRA            CPF
# 1                vaiane de souza              VAIANE DE SOUZA            CPF
# 2                       ABELARDO                     ABELARDO            CPF
# 3    Abelardo Ferreira da Silva   ABELARDO FERREIRA DA SILVA             CPF
# 4                   Adelio Costa                 Adelio Costa            CPF
# ..                           ...                          ...            ...
# 715                  Yeison cano                  Yeison cano            CPF
# 716               Yoichi Ricardo               Yoichi Ricardo            CPF
# 717                         Yoni                         Yoni            CPF
# 718                       Zaida                        Zaida             CPF
# 719                       Zilah                        ZILAH             CPF
#
# ...

# %%
# Lista de colunas para remover
colunas_para_remover = ['CNPJ_CPF', 'IE_RG', 'PASSAPORTE', 'NUMERO', 'CEP', 'COMPLEMENTO', 'CELULAR', 'NACIONALIDADE', 'EMAIL', 'TELEFONE', 'OBSERVACOES']

# Remover colunas do DataFrame (apenas as que existem)
df = df.drop(columns=[coluna for coluna in colunas_para_remover if coluna in df.columns])

display(df)
# Out:
#                             NOME                NOME_FANTASIA TIPO_DOCUMENTO  \
# 0                raquel teixeira              RAQUEL TEIXEIRA            CPF
# 1                vaiane de souza              VAIANE DE SOUZA            CPF
# 2                       ABELARDO                     ABELARDO            CPF
# 3    Abelardo Ferreira da Silva   ABELARDO FERREIRA DA SILVA             CPF
# 4                   Adelio Costa                 Adelio Costa            CPF
# ..                           ...                          ...            ...
# 715                  Yeison cano                  Yeison cano            CPF
# 716               Yoichi Ricardo               Yoichi Ricardo            CPF
# 717                         Yoni                         Yoni            CPF
# 718                       Zaida                        Zaida             CPF
# 719                       Zilah                        ZILAH             CPF
#
# ...
